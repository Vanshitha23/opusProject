# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# ---------------- LOAD DATA ----------------
data = pd.read_csv("merchant_risk_dataset_100k.csv")

# ---------------- FEATURES ----------------
features = [
    "RefundRate",
    "ChargebackRate",
    "TxnGrowthRate",
    "AvgTransactionValue",
    "TransactionCount",
    "TotalVolume"
]

X = data[features].copy()
y = data["Anomaly_Label"]   # target

# ---------------- SCALE (optional but good) ----------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# ---------------- TRAIN MODEL ----------------
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_scaled, y)

# ---------------- FEATURE IMPORTANCE ----------------
importance = rf.feature_importances_

feature_importance = pd.DataFrame({
    "Feature": features,
    "Importance": importance
}).sort_values(by="Importance", ascending=False)

print(feature_importance)
# Out:
#                Feature  Importance
# 3  AvgTransactionValue    0.240613
# 5          TotalVolume    0.238899
# 4     TransactionCount    0.214084
# 0           RefundRate    0.162226
# 1       ChargebackRate    0.144178
# 2        TxnGrowthRate    0.000000
